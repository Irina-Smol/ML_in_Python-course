# %% [markdown]
# # Полезные методы
#
# Давайте изучим полезные методы и функции pandas. Это будет лишь небольшой набор из того, что доступно в Pandas. Дополнительные методы и функции очень удобно посмотреть в [документации](https://pandas.pydata.org/pandas-docs/stable/reference/index.html) .
#
# В данной лекции мы рассмотрим следующие функции и методы (можете нажать на ту или иную ссылку, чтобы перейти к соответствующей части блокнота):
#
# * [метод apply()](#apply_method)
# * [apply() с функцией](#apply_function)
# * [apply() с лямбда-выражением](#apply_lambda)
# * [apply() для нескольких колонок](#apply_multiple)
# * [describe()](#describe)
# * [sort_values()](#sort)
# * [corr()](#corr)
# * [idxmin и idxmax](#idx)
# * [value_counts](#v_c)
# * [replace](#replace)
# * [unique и nunique](#uni)
# * [map](#map)
# * [duplicated и drop_duplicates](#dup)
# * [between](#bet)
# * [sample](#sample)
# * [nlargest](#n)

# %% [markdown]
# <a id='apply_method'></a>
#
# ## Метод .apply()
#
# Здесь мы рассмотрим очень полезный метод **apply** - он позволяет применить ту или иную функцию сразу для всех значений колонки DataFrame (в режиме broadcast).

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('tips.csv')

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %% [markdown]
# <a id='apply_function'></a>
# ### apply с функцией

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   total_bill        244 non-null    float64
#  1   tip               244 non-null    float64
#  2   sex               244 non-null    object
#  3   smoker            244 non-null    object
#  4   day               244 non-null    object
#  5   time              244 non-null    object
#  6   size              244 non-null    int64
#  7   price_per_person  244 non-null    float64
#  8   Payer Name        244 non-null    object
#  9   CC Number         244 non-null    int64
#  10  Payment ID        244 non-null    object
# dtypes: float64(3), int64(2), object(6)
# memory usage: 21.1+ KB

# %%
def last_four(num):  # задача: взять последние 4 цифры из номера в графе CC Number
    return str(num)[-4:]

# %%
df['CC Number'][0]
# Out:
# 3560325168603410

# %%
last_four(3560325168603410)
# Out:
# '3410'

# %%
df['last_four'] = df['CC Number'].apply(last_four)

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID last_four
# 0  Christy Cunningham  3560325168603410    Sun2959      3410
# 1      Douglas Tucker  4478071379779230    Sun4608      9230
# 2      Travis Walters  6011812112971322    Sun4458      1322
# 3    Nathaniel Harris  4676137647685994    Sun5260      5994
# 4        Tonya Carter  4832732618637221    Sun2251      7221

# %% [markdown]
# ### Применение .apply() для более сложных функций

# %%
df['total_bill'].mean()
# Out:
# 19.785942622950824

# %%
def yelp(price):
    if price < 10:
        return '$'
    elif price >= 10 and price < 30:
        return '$$'
    else:
        return '$$$'

# %%
df['Expensive'] = df['total_bill'].apply(yelp)

# %%
# df

# %% [markdown]
# <a id='apply_lambda'></a>
# ### apply с lambda-выражением

# %%
def simple(num):
    return num*2

# %%
lambda num: num*2
# Out:
# <function __main__.<lambda>(num)>

# %%
df['total_bill'].apply(lambda bill: bill*0.18)
# Out:
# 0      3.0582
# 1      1.8612
# 2      3.7818
# 3      4.2624
# 4      4.4262
#         ...
# 239    5.2254
# 240    4.8924
# 241    4.0806
# 242    3.2076
# 243    3.3804
# Name: total_bill, Length: 244, dtype: float64

# %% [markdown]
# <a id='apply_multiple'></a>
# ## apply с несколькими колонками
#
# Обратите внимание, что есть несколько различных способов применить apply для нескольких колонок:
#
# https://stackoverflow.com/questions/19914937/applying-function-with-multiple-arguments-to-create-a-new-pandas-column

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID last_four Expensive
# 0  Christy Cunningham  3560325168603410    Sun2959      3410        $$
# 1      Douglas Tucker  4478071379779230    Sun4608      9230        $$
# 2      Travis Walters  6011812112971322    Sun4458      1322        $$
# 3    Nathaniel Harris  4676137647685994    Sun5260      5994        $$
# 4        Tonya Carter  4832732618637221    Sun2251      7221        $$

# %%
def quality(total_bill,tip):
    if tip/total_bill  > 0.25:
        return "Generous"
    else:
        return "Other"

# %%
df['Tip Quality'] = df[['total_bill','tip']].apply(lambda df: quality(df['total_bill'],df['tip']),axis=1)

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID last_four Expensive  \
# 0  Christy Cunningham  3560325168603410    Sun2959      3410        $$
# 1      Douglas Tucker  4478071379779230    Sun4608      9230        $$
# 2      Travis Walters  6011812112971322    Sun4458      1322        $$
# 3    Nathaniel Harris  4676137647685994    Sun5260      5994        $$
# 4        Tonya Carter  4832732618637221    Sun2251      7221        $$
#
#   Tip Quality
# 0       Other
# 1       Other
# 2       Other
# 3       Other
# 4       Other

# %%
import numpy as np

# %%
df['Tip Quality'] = np.vectorize(quality)(df['total_bill'], df['tip'])

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID last_four Expensive  \
# 0  Christy Cunningham  3560325168603410    Sun2959      3410        $$
# 1      Douglas Tucker  4478071379779230    Sun4608      9230        $$
# 2      Travis Walters  6011812112971322    Sun4458      1322        $$
# 3    Nathaniel Harris  4676137647685994    Sun5260      5994        $$
# 4        Tonya Carter  4832732618637221    Sun2251      7221        $$
#
#   Tip Quality
# 0       Other
# 1       Other
# 2       Other
# 3       Other
# 4       Other

# %% [markdown]
# Какой из способов быстрее?

# %%
import timeit # на вход подаются фрагменты кода в виде текста,1 раз выполняется команда setup, затем команды stmt_one и stmt_two
              # эти команды выполняются много раз в цикле, на выходе - время выполнения команд
  
# этот фрагмент кода будет запускаться только один раз
setup = '''
import numpy as np
import pandas as pd
df = pd.read_csv('tips.csv')
def quality(total_bill,tip):
    if tip/total_bill  > 0.25:
        return "Generous"
    else:
        return "Other"
'''
  
# это фрагменты кода, для которых будет измеряться время выполнения
# (они будут выполняться много раз)
stmt_one = ''' 
df['Tip Quality'] = df[['total_bill','tip']].apply(lambda df: quality(df['total_bill'],df['tip']),axis=1)
'''

stmt_two = '''
df['Tip Quality'] = np.vectorize(quality)(df['total_bill'], df['tip'])
'''

# %%
timeit.timeit(setup = setup, 
                    stmt = stmt_one, 
                    number = 1000) # метод один раз вызовет setup, затем 1000 раз команду stmt_one
# Out:
# 2.4701358000002074

# %%
timeit.timeit(setup = setup, 
                    stmt = stmt_two, 
                    number = 1000)
# Out:
# 0.15836129999979676

# %% [markdown]
# Векторизация работает намного быстрее! **np.vectorize()**.
#
# Детальное описание vectorize:
# https://docs.scipy.org/doc/numpy/reference/generated/numpy.vectorize.html

# %% [markdown]
# <a id='describe'></a>
# ### df.describe для суммарных статистик

# %%
df.describe() # основные характеристики для числовых колонок
# Out:
#        total_bill         tip        size  price_per_person     CC Number
# count  244.000000  244.000000  244.000000        244.000000  2.440000e+02
# mean    19.785943    2.998279    2.569672          7.888197  2.563496e+15
# std      8.902412    1.383638    0.951100          2.914234  2.369340e+15
# min      3.070000    1.000000    1.000000          2.880000  6.040679e+10
# 25%     13.347500    2.000000    2.000000          5.800000  3.040731e+13
# 50%     17.795000    2.900000    2.000000          7.255000  3.525318e+15
# 75%     24.127500    3.562500    3.000000          9.390000  4.553675e+15
# max     50.810000   10.000000    6.000000         20.270000  6.596454e+15

# %%
df.describe().transpose() # транспонирование
# Out:
#                   count          mean           std           min  \
# total_bill        244.0  1.978594e+01  8.902412e+00  3.070000e+00
# tip               244.0  2.998279e+00  1.383638e+00  1.000000e+00
# size              244.0  2.569672e+00  9.510998e-01  1.000000e+00
# price_per_person  244.0  7.888197e+00  2.914234e+00  2.880000e+00
# CC Number         244.0  2.563496e+15  2.369340e+15  6.040679e+10
#
#                            25%           50%           75%           max
# total_bill        1.334750e+01  1.779500e+01  2.412750e+01  5.081000e+01
# tip               2.000000e+00  2.900000e+00  3.562500e+00  1.000000e+01
# size              2.000000e+00  2.000000e+00  3.000000e+00  6.000000e+00
# price_per_person  5.800000e+00  7.255000e+00  9.390000e+00  2.027000e+01
# CC Number         3.040731e+13  3.525318e+15  4.553675e+15  6.596454e+15

# %% [markdown]
# <a id='sort'></a>
# ### sort_values()

# %%
df.sort_values('tip') # отсортировать данные по колонке (в порядке возрастания)
# Out:
#      total_bill    tip     sex smoker   day    time  size  price_per_person  \
# 67         3.07   1.00  Female    Yes   Sat  Dinner     1              3.07
# 236       12.60   1.00    Male    Yes   Sat  Dinner     2              6.30
# 92         5.75   1.00  Female    Yes   Fri  Dinner     2              2.88
# 111        7.25   1.00  Female     No   Sat  Dinner     1              7.25
# 0         16.99   1.01  Female     No   Sun  Dinner     2              8.49
# ..          ...    ...     ...    ...   ...     ...   ...               ...
# 141       34.30   6.70    Male     No  Thur   Lunch     6              5.72
# 59        48.27   6.73    Male     No   Sat  Dinner     4             12.07
# 23        39.42   7.58    Male     No   Sat  Dinner     4              9.86
# 212       48.33   9.00    Male     No   Sat  Dinner     4             12.08
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3             16.94
#
#              Payer Name         CC Number Payment ID last_four Expensive  \
# 67        Tiffany Brock  4359488526995267    Sat3455      5267         $
# 236       Matthew Myers  3543676378973965    Sat5032      3965        $$
# 92         Leah Ramirez  3508911676966392    Fri3780      6392         $
# 111         Terri Jones  3559221007826887    Sat4801      6887         $
# 0    Christy Cunningham  3560325168603410    Sun2959      3410        $$
# ..                  ...               ...        ...       ...       ...
# 141      Steven Carlson  3526515703718508   Thur1025      8508       $$$
# 59          Brian Ortiz  6596453823950595    Sat8139      0595       $$$
# 23       Lance Peterson  3542584061609808     Sat239      9808       $$$
# 212     Alex Williamson      676218815212    Sat4590      5212       $$$
# 170       Gregory Clark  5473850968388236    Sat1954      8236       $$$
#
#     Tip Quality
# 67     Generous
# 236       Other
# 92        Other
# 111       Other
# 0         Other
# ..          ...
# 141       Other
# 59        Other
# 23        Other
# 212       Other
# 170       Other
#
# [244 rows x 14 columns]

# %%
df.sort_values('tip', ascending=False) # отсортировать данные по колонке (в порядке убывания)
# Out:
#      total_bill    tip     sex smoker   day    time  size  price_per_person  \
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3             16.94
# 212       48.33   9.00    Male     No   Sat  Dinner     4             12.08
# 23        39.42   7.58    Male     No   Sat  Dinner     4              9.86
# 59        48.27   6.73    Male     No   Sat  Dinner     4             12.07
# 141       34.30   6.70    Male     No  Thur   Lunch     6              5.72
# ..          ...    ...     ...    ...   ...     ...   ...               ...
# 0         16.99   1.01  Female     No   Sun  Dinner     2              8.49
# 236       12.60   1.00    Male    Yes   Sat  Dinner     2              6.30
# 111        7.25   1.00  Female     No   Sat  Dinner     1              7.25
# 67         3.07   1.00  Female    Yes   Sat  Dinner     1              3.07
# 92         5.75   1.00  Female    Yes   Fri  Dinner     2              2.88
#
#              Payer Name         CC Number Payment ID last_four Expensive  \
# 170       Gregory Clark  5473850968388236    Sat1954      8236       $$$
# 212     Alex Williamson      676218815212    Sat4590      5212       $$$
# 23       Lance Peterson  3542584061609808     Sat239      9808       $$$
# 59          Brian Ortiz  6596453823950595    Sat8139      0595       $$$
# 141      Steven Carlson  3526515703718508   Thur1025      8508       $$$
# ..                  ...               ...        ...       ...       ...
# 0    Christy Cunningham  3560325168603410    Sun2959      3410        $$
# 236       Matthew Myers  3543676378973965    Sat5032      3965        $$
# 111         Terri Jones  3559221007826887    Sat4801      6887         $
# 67        Tiffany Brock  4359488526995267    Sat3455      5267         $
# 92         Leah Ramirez  3508911676966392    Fri3780      6392         $
#
#     Tip Quality
# 170       Other
# 212       Other
# 23        Other
# 59        Other
# 141       Other
# ..          ...
# 0         Other
# 236       Other
# 111       Other
# 67     Generous
# 92        Other
#
# [244 rows x 14 columns]

# %%
# Бывает полезно, если Вы хотите поменять порядок колонок в DataFrame после сортировки
# https://stackoverflow.com/questions/13148429/how-to-change-the-order-of-dataframe-columns
df.sort_values(['tip','size']) # отсортировать по нескольким колонкам (сначала tip потом size)
# df.sort_values(['tip','size'], ascending=True)
# Out:
#      total_bill    tip     sex smoker   day    time  size  price_per_person  \
# 67         3.07   1.00  Female    Yes   Sat  Dinner     1              3.07
# 111        7.25   1.00  Female     No   Sat  Dinner     1              7.25
# 92         5.75   1.00  Female    Yes   Fri  Dinner     2              2.88
# 236       12.60   1.00    Male    Yes   Sat  Dinner     2              6.30
# 0         16.99   1.01  Female     No   Sun  Dinner     2              8.49
# ..          ...    ...     ...    ...   ...     ...   ...               ...
# 141       34.30   6.70    Male     No  Thur   Lunch     6              5.72
# 59        48.27   6.73    Male     No   Sat  Dinner     4             12.07
# 23        39.42   7.58    Male     No   Sat  Dinner     4              9.86
# 212       48.33   9.00    Male     No   Sat  Dinner     4             12.08
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3             16.94
#
#              Payer Name         CC Number Payment ID last_four Expensive  \
# 67        Tiffany Brock  4359488526995267    Sat3455      5267         $
# 111         Terri Jones  3559221007826887    Sat4801      6887         $
# 92         Leah Ramirez  3508911676966392    Fri3780      6392         $
# 236       Matthew Myers  3543676378973965    Sat5032      3965        $$
# 0    Christy Cunningham  3560325168603410    Sun2959      3410        $$
# ..                  ...               ...        ...       ...       ...
# 141      Steven Carlson  3526515703718508   Thur1025      8508       $$$
# 59          Brian Ortiz  6596453823950595    Sat8139      0595       $$$
# 23       Lance Peterson  3542584061609808     Sat239      9808       $$$
# 212     Alex Williamson      676218815212    Sat4590      5212       $$$
# 170       Gregory Clark  5473850968388236    Sat1954      8236       $$$
#
#     Tip Quality
# 67     Generous
# 111       Other
# 92        Other
# 236       Other
# 0         Other
# ..          ...
# 141       Other
# 59        Other
# 23        Other
# 212       Other
# 170       Other
#
# [244 rows x 14 columns]

# %% [markdown]
# <a id='corr'></a>
# ## df.corr() для проверки корреляции
#
# [Корреляция в Википедии](https://ru.wikipedia.org/wiki/%D0%9A%D0%BE%D1%80%D1%80%D0%B5%D0%BB%D1%8F%D1%86%D0%B8%D1%8F)

# %%
df.corr()
# Out:
#                   total_bill       tip      size  price_per_person  CC Number
# total_bill          1.000000  0.675734  0.598315          0.647554   0.104576
# tip                 0.675734  1.000000  0.489299          0.347405   0.110857
# size                0.598315  0.489299  1.000000         -0.175359  -0.030239
# price_per_person    0.647554  0.347405 -0.175359          1.000000   0.135240
# CC Number           0.104576  0.110857 -0.030239          0.135240   1.000000

# %%
df[['total_bill','tip']].corr()
# Out:
#             total_bill       tip
# total_bill    1.000000  0.675734
# tip           0.675734  1.000000

# %% [markdown]
# <a id='idx'></a>
# ### idxmin и idxmax

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID last_four Expensive  \
# 0  Christy Cunningham  3560325168603410    Sun2959      3410        $$
# 1      Douglas Tucker  4478071379779230    Sun4608      9230        $$
# 2      Travis Walters  6011812112971322    Sun4458      1322        $$
# 3    Nathaniel Harris  4676137647685994    Sun5260      5994        $$
# 4        Tonya Carter  4832732618637221    Sun2251      7221        $$
#
#   Tip Quality
# 0       Other
# 1       Other
# 2       Other
# 3       Other
# 4       Other

# %%
df['total_bill'].max()
# Out:
# 50.81

# %%
df['total_bill'].idxmax()
# Out:
# 170

# %%
df['total_bill'].idxmin()
# Out:
# 67

# %%
df.iloc[67]
# Out:
# total_bill                      3.07
# tip                              1.0
# sex                           Female
# smoker                           Yes
# day                              Sat
# time                          Dinner
# size                               1
# price_per_person                3.07
# Payer Name             Tiffany Brock
# CC Number           4359488526995267
# Payment ID                   Sat3455
# last_four                       5267
# Expensive                          $
# Tip Quality                 Generous
# Name: 67, dtype: object

# %%
df.iloc[170]
# Out:
# total_bill                     50.81
# tip                             10.0
# sex                             Male
# smoker                           Yes
# day                              Sat
# time                          Dinner
# size                               3
# price_per_person               16.94
# Payer Name             Gregory Clark
# CC Number           5473850968388236
# Payment ID                   Sat1954
# last_four                       8236
# Expensive                        $$$
# Tip Quality                    Other
# Name: 170, dtype: object

# %% [markdown]
# <a id='v_c'></a>
# ### value_counts
#
# Удобный способ быстро посчитать количество строк для той или иной категории. Имеет смысл только для колонок, принимающих [категорийные (категориальные/дискретные) значения](https://ru.wikipedia.org/wiki/%D0%9A%D0%B0%D1%87%D0%B5%D1%81%D1%82%D0%B2%D0%B5%D0%BD%D0%BD%D0%B0%D1%8F_%D0%BF%D0%B5%D1%80%D0%B5%D0%BC%D0%B5%D0%BD%D0%BD%D0%B0%D1%8F).

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID last_four Expensive  \
# 0  Christy Cunningham  3560325168603410    Sun2959      3410        $$
# 1      Douglas Tucker  4478071379779230    Sun4608      9230        $$
# 2      Travis Walters  6011812112971322    Sun4458      1322        $$
# 3    Nathaniel Harris  4676137647685994    Sun5260      5994        $$
# 4        Tonya Carter  4832732618637221    Sun2251      7221        $$
#
#   Tip Quality
# 0       Other
# 1       Other
# 2       Other
# 3       Other
# 4       Other

# %%
df['sex'].value_counts()
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64

# %%
df['day'].unique() # уникальные значения колонки
# Out:
# array(['Sun', 'Sat', 'Thur', 'Fri'], dtype=object)

# %%
df['day'].nunique() # количество уникальных значений
# Out:
# 4

# %%
df['day'].value_counts()
# Out:
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: day, dtype: int64

# %% [markdown]
# <a id='replace'></a>
#
# ### replace
#
# Заменяет одно значение другим.

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID last_four Expensive  \
# 0  Christy Cunningham  3560325168603410    Sun2959      3410        $$
# 1      Douglas Tucker  4478071379779230    Sun4608      9230        $$
# 2      Travis Walters  6011812112971322    Sun4458      1322        $$
# 3    Nathaniel Harris  4676137647685994    Sun5260      5994        $$
# 4        Tonya Carter  4832732618637221    Sun2251      7221        $$
#
#   Tip Quality
# 0       Other
# 1       Other
# 2       Other
# 3       Other
# 4       Other

# %%
df['Tip Quality'].replace(to_replace='Other',value='Ok')
# Out:
# 0      Ok
# 1      Ok
# 2      Ok
# 3      Ok
# 4      Ok
#        ..
# 239    Ok
# 240    Ok
# 241    Ok
# 242    Ok
# 243    Ok
# Name: Tip Quality, Length: 244, dtype: object

# %%
df['Tip Quality'] = df['Tip Quality'].replace(to_replace='Other',value='Ok')

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID last_four Expensive  \
# 0  Christy Cunningham  3560325168603410    Sun2959      3410        $$
# 1      Douglas Tucker  4478071379779230    Sun4608      9230        $$
# 2      Travis Walters  6011812112971322    Sun4458      1322        $$
# 3    Nathaniel Harris  4676137647685994    Sun5260      5994        $$
# 4        Tonya Carter  4832732618637221    Sun2251      7221        $$
#
#   Tip Quality
# 0          Ok
# 1          Ok
# 2          Ok
# 3          Ok
# 4          Ok

# %%
df['sex'] = df['sex'].replace(['Female', 'Male'], ['F', 'M'])
df.head()
# Out:
#    total_bill   tip sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01   F     No  Sun  Dinner     2              8.49
# 1       10.34  1.66   M     No  Sun  Dinner     3              3.45
# 2       21.01  3.50   M     No  Sun  Dinner     3              7.00
# 3       23.68  3.31   M     No  Sun  Dinner     2             11.84
# 4       24.59  3.61   F     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID last_four Expensive  \
# 0  Christy Cunningham  3560325168603410    Sun2959      3410        $$
# 1      Douglas Tucker  4478071379779230    Sun4608      9230        $$
# 2      Travis Walters  6011812112971322    Sun4458      1322        $$
# 3    Nathaniel Harris  4676137647685994    Sun5260      5994        $$
# 4        Tonya Carter  4832732618637221    Sun2251      7221        $$
#
#   Tip Quality
# 0          Ok
# 1          Ok
# 2          Ok
# 3          Ok
# 4          Ok

# %% [markdown]
# <a id='uni'></a>
# ### unique

# %%
df['size'].unique()
# Out:
# array([2, 3, 4, 1, 6, 5], dtype=int64)

# %%
df['size'].nunique()
# Out:
# 6

# %%
df['time'].unique()
# Out:
# array(['Dinner', 'Lunch'], dtype=object)

# %% [markdown]
# <a id='map'></a>
# ### map

# %%
my_map = {'Dinner':'D','Lunch':'L'}

# %%
df['time'].map(my_map)
# Out:
# 0      D
# 1      D
# 2      D
# 3      D
# 4      D
#       ..
# 239    D
# 240    D
# 241    D
# 242    D
# 243    D
# Name: time, Length: 244, dtype: object

# %%
df.head()
# Out:
#    total_bill   tip sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01   F     No  Sun  Dinner     2              8.49
# 1       10.34  1.66   M     No  Sun  Dinner     3              3.45
# 2       21.01  3.50   M     No  Sun  Dinner     3              7.00
# 3       23.68  3.31   M     No  Sun  Dinner     2             11.84
# 4       24.59  3.61   F     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID last_four Expensive  \
# 0  Christy Cunningham  3560325168603410    Sun2959      3410        $$
# 1      Douglas Tucker  4478071379779230    Sun4608      9230        $$
# 2      Travis Walters  6011812112971322    Sun4458      1322        $$
# 3    Nathaniel Harris  4676137647685994    Sun5260      5994        $$
# 4        Tonya Carter  4832732618637221    Sun2251      7221        $$
#
#   Tip Quality
# 0          Ok
# 1          Ok
# 2          Ok
# 3          Ok
# 4          Ok

# %% [markdown]
# <a id='dup'></a>
# ## Дубликаты
#
# ### .duplicated() и .drop_duplicates()
#
#
# .duplicated() возвращает True для строк-дубликатов. Если есть несколько одинаковых строк, то для первой строки будет False, а для остальных True, потому что остальные - это дубликаты первой строки.

# %%
simple_df = pd.DataFrame([1,2,2,2],['a','b','c','d'])

# %%
simple_df
# Out:
#    0
# a  1
# b  2
# c  2
# d  2

# %%
simple_df.duplicated()
# Out:
# a    False
# b    False
# c     True
# d     True
# dtype: bool

# %%
simple_df.drop_duplicates() # удаляет дубликаты
# Out:
#    0
# a  1
# b  2

# %% [markdown]
# <a id='bet'></a>
# ## between
#
# Первый параметр - left - левая граница диапазона;
# Второй параметр - right - правая граница диапазона;
# Третий параметр - inclusive - включать ли границы диапазона. Значение Boolean, по умолчанию True. Если указать False, то границы не включаются в проверяемый диапазон.

# %%
df['total_bill'].between(10,20,inclusive=True) # inclusive - чтобы включать верхнюю границу в диапазон
# Out:
# C:\Users\Ирина\AppData\Local\Temp\ipykernel_3644\2451624966.py:1: FutureWarning: Boolean inputs to the `inclusive` argument are deprecated in favour of `both` or `neither`.
#   df['total_bill'].between(10,20,inclusive=True) # inclusive - чтобы включать верхнюю границу в диапазон
# 0       True
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 239    False
# 240    False
# 241    False
# 242     True
# 243     True
# Name: total_bill, Length: 244, dtype: bool

# %%
df[df['total_bill'].between(10,20,inclusive=True)] # выбор по условию (те строки, в которых сумма счета от 10 до 20)
# Out:
# C:\Users\Ирина\AppData\Local\Temp\ipykernel_3644\1634259892.py:1: FutureWarning: Boolean inputs to the `inclusive` argument are deprecated in favour of `both` or `neither`.
#   df[df['total_bill'].between(10,20,inclusive=True)] # выбор по условию (те строки, в которых сумма счета от 10 до 20)
#      total_bill   tip sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01   F     No   Sun  Dinner     2              8.49
# 1         10.34  1.66   M     No   Sun  Dinner     3              3.45
# 8         15.04  1.96   M     No   Sun  Dinner     2              7.52
# 9         14.78  3.23   M     No   Sun  Dinner     2              7.39
# 10        10.27  1.71   M     No   Sun  Dinner     2              5.14
# ..          ...   ...  ..    ...   ...     ...   ...               ...
# 234       15.53  3.00   M    Yes   Sat  Dinner     2              7.76
# 235       10.07  1.25   M     No   Sat  Dinner     2              5.04
# 236       12.60  1.00   M    Yes   Sat  Dinner     2              6.30
# 242       17.82  1.75   M     No   Sat  Dinner     2              8.91
# 243       18.78  3.00   F     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID last_four Expensive  \
# 0    Christy Cunningham  3560325168603410    Sun2959      3410        $$
# 1        Douglas Tucker  4478071379779230    Sun4608      9230        $$
# 8       Joseph Mcdonald  3522866365840377    Sun6820      0377        $$
# 9         Jerome Abbott  3532124519049786    Sun3775      9786        $$
# 10        William Riley      566287581219    Sun2546      1219        $$
# ..                  ...               ...        ...       ...       ...
# 234       Tracy Douglas  4097938155941930    Sat7220      1930        $$
# 235       Sean Gonzalez  3534021246117605    Sat4615      7605        $$
# 236       Matthew Myers  3543676378973965    Sat5032      3965        $$
# 242        Dennis Dixon     4375220550950      Sat17      0950        $$
# 243     Michelle Hardin  3511451626698139    Thur672      8139        $$
#
#     Tip Quality
# 0            Ok
# 1            Ok
# 8            Ok
# 9            Ok
# 10           Ok
# ..          ...
# 234          Ok
# 235          Ok
# 236          Ok
# 242          Ok
# 243          Ok
#
# [130 rows x 14 columns]

# %% [markdown]
# <a id='sample'></a>
# ## sample

# %%
df.sample(5) # получить случайные 5 строк
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 216       28.15  3.00    Male    Yes   Sat  Dinner     5              5.63
# 136       10.33  2.00  Female     No  Thur   Lunch     2              5.16
# 13        18.43  3.00    Male     No   Sun  Dinner     4              4.61
# 146       18.64  1.36  Female     No  Thur   Lunch     3              6.21
# 56        38.01  3.00    Male    Yes   Sat  Dinner     4              9.50
#
#                 Payer Name         CC Number Payment ID last_four Expensive  \
# 216      Shawn Barnett PhD     4590982568244    Sat7320      8244        $$
# 136            Donna Kelly   180048553626376   Thur1393      6376        $$
# 13            Joshua Jones  6011163105616890    Sun2971      6890        $$
# 146          Kelly Estrada       60463302327   Thur3941      2327        $$
# 56   James Christensen DDS   349793629453226    Sat8903      3226       $$$
#
#     Tip Quality
# 216          Ok
# 136          Ok
# 13           Ok
# 146          Ok
# 56           Ok

# %%
df.sample(frac=0.1) # frac - доля от кол-ва строк (1/10 всех строк (10%))
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 73        25.28  5.00  Female    Yes   Sat  Dinner     2             12.64
# 141       34.30  6.70    Male     No  Thur   Lunch     6              5.72
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 237       32.83  1.17    Male    Yes   Sat  Dinner     2             16.42
# 69        15.01  2.09    Male    Yes   Sat  Dinner     2              7.50
# 108       18.24  3.76    Male     No   Sat  Dinner     2              9.12
# 85        34.83  5.17  Female     No  Thur   Lunch     4              8.71
# 156       48.17  5.00    Male     No   Sun  Dinner     6              8.03
# 196       10.34  2.00    Male    Yes  Thur   Lunch     2              5.17
# 41        17.46  2.54    Male     No   Sun  Dinner     2              8.73
# 236       12.60  1.00    Male    Yes   Sat  Dinner     2              6.30
# 225       16.27  2.50  Female    Yes   Fri   Lunch     2              8.14
# 61        13.81  2.00    Male    Yes   Sat  Dinner     2              6.90
# 203       16.40  2.50  Female    Yes  Thur   Lunch     2              8.20
# 5         25.29  4.71    Male     No   Sun  Dinner     4              6.32
# 220       12.16  2.20    Male    Yes   Fri   Lunch     2              6.08
# 119       24.08  2.92  Female     No  Thur   Lunch     4              6.02
# 96        27.28  4.00    Male    Yes   Fri  Dinner     2             13.64
# 159       16.49  2.00    Male     No   Sun  Dinner     4              4.12
# 26        13.37  2.00    Male     No   Sat  Dinner     2              6.68
# 129       22.82  2.18    Male     No  Thur   Lunch     3              7.61
# 21        20.29  2.75  Female     No   Sat  Dinner     2             10.14
# 94        22.75  3.25  Female     No   Fri  Dinner     2             11.38
# 39        31.27  5.00    Male     No   Sat  Dinner     3             10.42
#
#             Payer Name         CC Number Payment ID last_four Expensive  \
# 73        Julie Holmes  5418689346409571    Sat6065      9571        $$
# 141     Steven Carlson  3526515703718508   Thur1025      8508       $$$
# 239      Michael Avila  5296068606052842    Sat2657      2842        $$
# 237       Thomas Brown  4284722681265508    Sat2929      5508       $$$
# 69           Adam Hall  4700924377057571     Sat855      7571        $$
# 108       Steven Grant  4112810433473856    Sat6376      3856        $$
# 85         Shawna Cook  6011787464177340   Thur7972      7340       $$$
# 156      Ryan Gonzales  3523151482063321    Sun7518      3321       $$$
# 196        Eric Martin    30442491190342   Thur9862      0342        $$
# 41         David Boyer  3536678244278149    Sun9460      8149        $$
# 236      Matthew Myers  3543676378973965    Sat5032      3965        $$
# 225     Whitney Arnold  3579111947217428    Fri6665      7428        $$
# 61      Ryan Hernandez     4766834726806    Sat3030      6806        $$
# 203        Toni Brooks  3582289985920239   Thur7770      0239        $$
# 5           Erik Smith   213140353657882    Sun9679      7882        $$
# 220      Ricky Johnson   213109508670736    Fri4607      0736        $$
# 119     Melanie Jordan      676212062720   Thur8063      2720        $$
# 96         Eric Carter  4563054452787961    Fri3159      7961        $$
# 159   Christopher Soto    30501814271434    Sun1781      1434        $$
# 26          Kyle Avery  6531339539615499    Sat6651      5499        $$
# 129     Raymond Torres     4855776744024   Thur9424      4024        $$
# 21     Natalie Gardner  5448125351489749    Sat9618      9749        $$
# 94         Jamie Garza      676318332068    Fri2318      2068        $$
# 39   Mr. Brandon Berry  6011525851069856    Sat6373      9856       $$$
#
#     Tip Quality
# 73           Ok
# 141          Ok
# 239          Ok
# 237          Ok
# 69           Ok
# 108          Ok
# 85           Ok
# 156          Ok
# 196          Ok
# 41           Ok
# 236          Ok
# 225          Ok
# 61           Ok
# 203          Ok
# 5            Ok
# 220          Ok
# 119          Ok
# 96           Ok
# 159          Ok
# 26           Ok
# 129          Ok
# 21           Ok
# 94           Ok
# 39           Ok

# %% [markdown]
# <a id='n'></a>
# ## nlargest и nsmallest

# %%
df.nlargest(10,'tip')
# Out:
#      total_bill    tip     sex smoker   day    time  size  price_per_person  \
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3             16.94
# 212       48.33   9.00    Male     No   Sat  Dinner     4             12.08
# 23        39.42   7.58    Male     No   Sat  Dinner     4              9.86
# 59        48.27   6.73    Male     No   Sat  Dinner     4             12.07
# 141       34.30   6.70    Male     No  Thur   Lunch     6              5.72
# 183       23.17   6.50    Male    Yes   Sun  Dinner     4              5.79
# 214       28.17   6.50  Female    Yes   Sat  Dinner     3              9.39
# 47        32.40   6.00    Male     No   Sun  Dinner     4              8.10
# 239       29.03   5.92    Male     No   Sat  Dinner     3              9.68
# 88        24.71   5.85    Male     No  Thur   Lunch     2             12.36
#
#             Payer Name         CC Number Payment ID last_four Expensive  \
# 170      Gregory Clark  5473850968388236    Sat1954      8236       $$$
# 212    Alex Williamson      676218815212    Sat4590      5212       $$$
# 23      Lance Peterson  3542584061609808     Sat239      9808       $$$
# 59         Brian Ortiz  6596453823950595    Sat8139      0595       $$$
# 141     Steven Carlson  3526515703718508   Thur1025      8508       $$$
# 183  Dr. Michael James     4718501859162    Sun6059      9162        $$
# 214    Marissa Jackson  4922302538691962    Sat3374      1962        $$
# 47        James Barnes  3552002592874186    Sun9677      4186       $$$
# 239      Michael Avila  5296068606052842    Sat2657      2842        $$
# 88        Roger Taylor     4410248629955   Thur9003      9955        $$
#
#     Tip Quality
# 170          Ok
# 212          Ok
# 23           Ok
# 59           Ok
# 141          Ok
# 183    Generous
# 214          Ok
# 47           Ok
# 239          Ok
# 88           Ok

# %% [markdown]
# ----
